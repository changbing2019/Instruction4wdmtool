# %% [markdown]
# ###  Testing wdmtoolbox
#
# <p>
# This python script is just for illustration!
#     Enjoy!
# </p>

# %%
from wdmtoolbox import wdmtoolbox
import pandas as pd

# %%
filepath='EHM.wdm'
dsndf=pd.DataFrame(wdmtoolbox.listdsns(filepath))
dsndf.head(10)
# Out:
#                               1                        2    \
# dsn                             1                        2
# start_date       1950-01-01 00:00               2005-01-01
# end_date         2010-01-01 00:00               2006-10-31
# llsdat      [1950, 1, 1, 0, 0, 0]    [2005, 1, 1, 0, 0, 0]
# lledat      [2010, 1, 1, 0, 0, 0]  [2006, 10, 31, 0, 0, 0]
# tstep                           1                        1
# tcode                           3                        4
# tcode_name                      H                        D
# location                b'MOD807'                b'SUB018'
# scenario              b'COMPUTED'                 b'RADAR'
#
#                                 3                        4    \
# dsn                               3                        4
# start_date               2005-01-01               2005-01-01
# end_date                 2006-10-31               2006-10-31
# llsdat        [2005, 1, 1, 0, 0, 0]    [2005, 1, 1, 0, 0, 0]
# ...

# %%
ts101=wdmtoolbox.extract(filepath,1)
# Out:
# C:\ProgramData\Anaconda3\envs\testwdm\lib\site-packages\wdmtoolbox\wdmutil.py:732: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   dtype=pd.np.float64,
# C:\ProgramData\Anaconda3\envs\testwdm\lib\site-packages\wdmtoolbox\wdmutil.py:736: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   tmpval.replace(tsfill, pd.np.nan, inplace=True)

# %%
ts101.plot()
# Out:
# <AxesSubplot:xlabel='Datetime'>
